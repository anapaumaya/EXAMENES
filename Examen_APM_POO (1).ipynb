# %% [markdown]
# ## Examen
#
# * Es necesario seguir los lineamientos ya preestablecidos.
#
# * Habrá cero tolerancia al plagio.
#
# * Sólo podrás hacer uso de las libretas que tengas, no se permite el uso de ChatGPT.
#
# * Todas las soluciones deben presentarse de manera lógica. Se penalizará la ausencia de argumentos y de documentación.

# %% [markdown]
# ## Ana Paula Maya Chávez

# %% [markdown]
# **Ejercicio 1:**
#
# ¿Qué es una clase y por qué es útil? \\
# Define una clase con un ejemplo, dando todas sus características.
#
# ---

# %%
#Una clase es una estructura que programa que ayuda para definir un conjunto de métodos y atributos que describen a una entidad o a un objeto.
#Se usan para modelar entidades del mundo real o abstracto.
#Los objetos que son  creados a partir de una clase tienen las mismas propiedades y comportamientos  que la clase

# %%
#Ejemplo
class España():
  def __init__(self, capital, idioma, moneda):
    self.capital = capital
    self.idioma = idioma
    self.moneda = moneda

class Ingalterra():
  def _init_(self, capital, idioma, moneda):
    self.capital = capital
    self.idioma = idioma
    self.moneda = moneda


def EspañaId(self):
    print ("En España se habla español")

def EsapñaCap(self):
    print ("La capital de Esapaña es Madrid")

def Esapñamon(self):
    print ("La moneda de Esapña es el euro")

def InglaterraID(self):
    print ("En Ingalterra se habla inglés")

def InglaterraCap(self):
    print ("La capital de Inglaterra es Londres ")

def Inglaterramon(self):
    print ("La moneda de Inglaterra es la libra")


# Define dos variables que sean cursores
var1= EsapñaCap("Madrid")
var2 = Esapñamon("euro")
var3 = Inglaterramon("libra")


# Comenta tus resultados
#En este ejemplo  se define de cada país (España e Inglaterra)la información como la capital, idioma y moneda.
#A la hora que preguntesla variable responde por ejemplo la moneda de Esapña, la cual sería euro
# Out:
# La capital de Esapaña es Madrid
# La moneda de Esapña es el euro
# La moneda de Inglaterra es la libra

# %% [markdown]
# **Ejercicio 2:**
#
# En Python, un **constructor** es un método especial que se llama automáticamente cuando se crea un objeto. Se utiliza para inicializar los atributos del objeto y realizar cualquier tarea de configuración necesaria antes de su uso. \\
#
# Para este ejercicio contesta las siguientes preguntas:
#
#
# 1.   ¿Cuál es la sintaxis para definir un constructor dentro de una clase?
# 2.   Considera el siguiente código: \\
#
# ![constructor.png](data:image/png;base64,...)
#
# \\
# La clase 'Human' tiene un constructor que toma dos parametros, ¿cuáles son?

# %%
#1. La sintaxis para definir un construvtor dentro de una clase es _init_
#La clase Human que toma los dos parametros son la de legs y arms
#Para poder tomar los parametros se tiene que utilizar self por es en el ejemplo de arriba
# estan como self.legs y self.arms

# %% [markdown]
# 3. Crea dos atributos (definiciones y polimorfismos) asociados a la clase 'Human´.
#
# ---

# %%
class Humans:
  def _init_ (self,brazos, manos):
      self.brazos = brazos
      self.manos=manos

  def brazos(self):
    return self.brazos + " es como tiene el brazo  Pau "
    return self.manos + " es como tiene la mano  Javi "

# %%
my_parts = Humans()
my_parts.brazos()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-c7a466e6477b> in <cell line: 2>()
#       1 my_parts = Humans()
# ----> 2 my_parts.brazos()
#
# <ipython-input-54-e2914165bfc9> in brazos(self)
#       5
#       6   def brazos(self):
# ----> 7     return self.brazos + " es como tiene el brazo  Pau "
#       8     return self.manos + " es como tiene la mano  Javi "
#       9
#
# TypeError: unsupported operand type(s) for +: 'method' and 'str'

# %%
my_parts = Humans("Grande ", "Chiquita")
my_parts.manos()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-a923c213abea> in <cell line: 1>()
# ----> 1 my_parts = Humans("Grande ", "Chiquita")
#       2 my_parts.manos()
#
# TypeError: Humans() takes no arguments

# %% [markdown]
# **Ejercicio 3:**
#
# Indica si las siguientes afirmaciones son verdaderas o falsas:
#
#
#
# *   El primer parámetro del método '__ init() __' es siempre 'self' , que se refiere a la instancia de la clase que se está creando. Se pasa automáticamente al constructor cuando se instancia el objeto.
# *   Después de 'self', puedes definir cualquier otro parámetro necesario para inicializar los atributos del objeto.
# *   Cuando añades la función '__ init ()  __' , la clase heredada ya no hereda la función ' __ init () __ ' de la clase madre.
# *   En la programación orientada a objetos, las clases pueden heredar atributos y métodos de otras clases.
# *  Cuando hablamos de polimorfismos en Python, diferentes clases pueden ser tratadas como instancias de la misma superclase, independientemente de cómo implementen el mismo método.
#
# ---

# %%
#1. Verdadero:self siempre va a ser una convención para poder referisrse la clase que se esta creando
#2. Verdadero: siempres después del self puede deinifir otro parámtro ya que  se pasan al  cuando se instancia el objeto y se utilizan para configurar sus atributos.
#3. Falso: Cuando añades la función de init que es la herdera va a seguir existiendo la función de init
#Si la otra clase no tiene el init va aheredar el que va hacer de la clase madre
#4. verdadero: Esto hace que unna clase y una sublcase herede caracteristicas y el comportamiento de otra clase.
#5. Verdadero: Va a permitir que los objetos de diferentes clases que heredan de una misma superclase se comporten de manera igual.

# %% [markdown]
# **Ejercicio 4:** A partir de un diccionario, crea un DataFrame (que llamarás **precios_muestra**) que consista de dos columnas y que tenga 12 valores **flotantes** que eligirás de manera aleatoria en el intervalo (8,13). Etiqueta del 1 al 12 y llama a la columna de etiquetas Mes.
#
# 1.- Construye una función que calcule los rendimientos simples de cada columna.
#
# 2.- Las desviaciones estadísticas de los rendimientos ayudan a calcular la volatilidad del portafolio:
# $$\text{desviaciones}=(\text{rendimientos}-\text{media}(\text{rendimientos}))^2.$$
# Crea una función que calcule la media de las desviaciones y luego la volatilidad de tu portafolio (raíz cuadrada de la media de las desviaciones).
#
# 3.- Anualizamos la volatilidad escalándola (multiplicándola) por la raíz cuadrada del número de períodos por observación.
#
# Por lo tanto, para anualizar la volatilidad de una serie mensual, la multiplicamos por la raíz cuadrada de 12. Muestra la serie de la volatilidad anualizada.
#
# 4.- Realiza una gráfica de barras para los rendimientos y una gráfica en líneas para los precios.
#
# 5.- Calcula los rendimientos compuestos para cada columna y después anualiza los rendimientos.
#
# ---

# %%
import pandas as pd
d=pd.read_csv

# %%
import numpy as np

precios_muestra = [np.random.uniform(8,13) for _ in range(1,13)]

closed = np.random.randint (8,13)

# %%
precios_muestra
# Out:
# [10.591003569653317,
#  8.128313590272658,
#  9.037350377205547,
#  10.12342734375753,
#  9.870849901671129,
#  10.317877121824054,
#  9.38814353147366,
#  10.933921732290845,
#  12.319278029616157,
#  8.587659279810165,
#  10.586895535770571,
#  8.660340531725767]

# %%
import numpy as np

valores = np.random.rand(12)

# %%
diccionario = {
               "valores" : precios_muestra}


import pandas as pd


d = pd.DataFrame(diccionario,index=["Mes 1", "Mes 2", "Mes 3", "Mes 4", "Mes 5", "Mes 6", "Mes 7", "Mes 8", "Mes 9", "Mes 10", "Mes 11","Mes 12"], )
d
# Out:
#           valores
# Mes 1   10.591004
# Mes 2    8.128314
# Mes 3    9.037350
# Mes 4   10.123427
# Mes 5    9.870850
# Mes 6   10.317877
# Mes 7    9.388144
# Mes 8   10.933922
# Mes 9   12.319278
# Mes 10   8.587659
# Mes 11  10.586896
# Mes 12   8.660341

# %%
rendimientos= d.pct_change().dropna()
rendimientos
# Out:
#          valores
# Mes 2  -0.232527
# Mes 3   0.111836
# Mes 4   0.120176
# Mes 5  -0.024950
# Mes 6   0.045288
# Mes 7  -0.090109
# Mes 8   0.164652
# Mes 9   0.126703
# Mes 10 -0.302909
# Mes 11  0.232803
# Mes 12 -0.181975

# %%
media=d.mean()
media
# Out:
# valores    9.878755
# dtype: float64

# %%
desviacion=d.std()
desviacion
# Out:
# valores    1.186868
# dtype: float64

# %%
# Anualizamos
volatilidad=desviacion*(1/12)
volatilidad
# Out:
# valores    0.098906
# dtype: float64

# %%
#  gráfica
rendimientos.hist(bins=50)
# Out:
# array([[<Axes: title={'center': 'valores'}>]], dtype=object)

# %%
# módulos para la gráfica
import matplotlib.pyplot as plt
from pylab import plot
import seaborn as sns

# %%
d['valores'].plot(label="Valores",figsize=(10,5))
# Out:
# <Axes: >

# %%
#Rendimientos compuestos
rendimientos=(1+d).cumprod()-1
rendimientos
# Out:
#              valores
# Mes 1   1.059100e+01
# Mes 2   1.048063e+02
# Mes 3   1.061015e+03
# Mes 4   1.181225e+04
# Mes 5   1.284190e+05
# Mes 6   1.453441e+06
# Mes 7   1.509857e+07
# Mes 8   1.801851e+08
# Mes 9   2.399936e+09
# Mes 10  2.300976e+10
# Mes 11  2.666117e+11
# Mes 12  2.575560e+12

# %% [markdown]
# **Ejercicio 5:** Carga dos tickers y realiza los pasos del ejercicio anterior usando los tickers que elijas. Recuerda tomar en cuenta la ventana de tiempo que manejarás. Realiza un análisis estadístico (estadística descriptiva, histogramas y gráficas de series de tiempo).

# %%
import yfinance as yf

# %%
df = yf.download(["AMZN","GOOGL"], "2018-01-01", "2019-01-01")["Adj Close"]
df
# Out:
# [*********************100%%**********************]  2 of 2 completed
#                  AMZN      GOOGL
# Date
# 2018-01-02  59.450500  53.660500
# 2018-01-03  60.209999  54.576000
# 2018-01-04  60.479500  54.787998
# 2018-01-05  61.457001  55.514500
# 2018-01-08  62.343498  55.710499
# ...               ...        ...
# 2018-12-24  67.197998  49.233501
# 2018-12-26  73.544998  52.392502
# 2018-12-27  73.082001  52.645000
# 2018-12-28  73.901001  52.334000
# 2018-12-31  75.098503  52.248001
#
# [251 rows x 2 columns]

# %%
rendimientos= d.pct_change().dropna()
rendimientos
# Out:
#          valores
# Mes 2  -0.226553
# Mes 3   0.185651
# Mes 4   0.032216
# Mes 5   0.094978
# Mes 6  -0.075838
# Mes 7  -0.175879
# Mes 8   0.130205
# Mes 9   0.206164
# Mes 10 -0.155959
# Mes 11  0.106723
# Mes 12 -0.099070

# %%
media=d.mean()
media
# Out:
# valores    10.757673
# dtype: float64

# %%
desviacion=d.std()
desviacion
# Out:
# valores    1.047843
# dtype: float64

# %%
# Anualizamos
volatilidad=desviacion*(1/12)
volatilidad
# Out:
# valores    0.08732
# dtype: float64

# %%
#  gráfica
rendimientos.hist(bins=50)
# Out:
# array([[<Axes: title={'center': 'valores'}>]], dtype=object)

# %%
# módulos para la gráfica
import matplotlib.pyplot as plt
from pylab import plot
import seaborn as sns

# %%
d['valores'].plot(label="Valores",figsize=(10,5))
# Out:
# <Axes: >

# %%
#Rendimientos compuestos
rendimientos=(1+d).cumprod()-1
rendimientos
# Out:
#              valores
# Mes 1   1.151747e+01
# Mes 2   1.230251e+02
# Mes 3   1.432974e+03
# Mes 4   1.706650e+04
# Mes 5   2.208133e+05
# Mes 6   2.656920e+06
# Mes 7   2.681369e+07
# Mes 8   3.023470e+08
# Mes 9   4.049741e+09
# Mes 10  4.641546e+10
# Mes 11  5.838046e+11
# Mes 12  6.673353e+12
